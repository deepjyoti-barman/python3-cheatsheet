# %% [markdown]
# # CS50P - Lecture 0 - Functions and Variables

# %% [markdown]
# ### Notes
#
# - `print()`- This is a built-in Python function that displays output to the console/terminal.
# It takes whatever you pass to it and shows it on the screen.
# - `"hello, world!"` - This is a string (text data) enclosed in double quotes. In Python, you can
# use either double quotes (`"`) or single quotes (`'`) to define strings.
# - Command to execute: `python <file-name>.py`

# %%
# Program that prints hello, world! in console
print('hello, world!')
# Out:
# hello, world!

# %% [markdown]
# ### Notes
#
# - **Variable**: A variable is just a container for some value inside a computer
# - **Comments**: Comments are notes to yourself and others in your code, comments can also serve to
# be a to-do list for yourself
#
#     ```python
#     # Single line comment
#
#     '''
#     Multi
#     Line
#     Comment
#     '''
#     ```

# %%
# Ask the user for their name, remove leading/trailing whitespace, and convert to title-case
name = input("What's your name? ").strip().title()
print('PS-1: hello, ' + name)

# Syntax: print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
print('PS-2: hello, ', end='')
print(name)

print('PS-3: hello,', name)
print('PS-4: hello, ', name, sep='')

# Format string (F-string)
print(f'PS-5: hello, {name}')

# Splitting the name into first and last, then greeting with the first name
first, last = name.split(' ')
print(f'PS-6: hello, {first}')
# Out:
# PS-1: hello, Deepjyoti Barman
# PS-2: hello, Deepjyoti Barman
# PS-3: hello, Deepjyoti Barman
# PS-4: hello, Deepjyoti Barman
# PS-5: hello, Deepjyoti Barman
# PS-6: hello, Deepjyoti

# %%
# Arithmetic operations
x = int(input("What's the value of x? "))    # 3
y = int(input("What's the value of y? "))    # 1
print('PS-1:', x + y)                        # 4

# ---------------------------------------------------------------------------------------

p = float(input("What's the value of p? "))  # 999.5
q = float(input("What's the value of q? "))  # 0.5

# Rounding off the result and separate numeric output greater than 1000 with commas
# Syntax: round(number[, ndigits])
r = round(p + q)
print(f'PS-2: {r:,}')                        # 1,000

# ---------------------------------------------------------------------------------------
d = float(input("What's the value of d? "))  # 2
e = float(input("What's the value of e? "))  # 3

# Round off to 2 decimal places
f = round(d / e, 2)
print('PS-3:', f)                            # 0.67

# Round off to 2 decimal places with F-string
print(f'PS-4: {f:.2f}')                      # 0.67
# Out:
# PS-1: 4
# PS-2: 1,000
# PS-3: 0.67
# PS-4: 0.67

# %% [markdown]
# ### Notes
#
# - Functions are useful to avoid repeating the same code again and again, no need to reinvent
# the wheel
# - `def` stands for define, if and when we want to define, create or invent our own functions we can
# do so uring this keyword

# %%
# Defining and calling a function with a default parameter for personalized greeting
def hello(to='world'):
    print('hello,', to)

hello()
name = input('What\'s your name? ')
hello(name)
# Out:
# hello, world
# hello, Deepjyoti

# %% [markdown]
# ### Notes
#
# - If you use a function, it must already exist by the time we are calling it, else you are going
# to get a `NameError` stating that the function is not defined
# - Scope refers to a variable only existing in the context in which you define it

# %%
# Even though the following piece of code might work in jupyter notebooks or interactive Python shells
# But, it will raise an error because the function is called before its definition
# NameError: name 'hello' is not defined. Did you mean: 'help'?
hello()
name = input('What\'s your name? ')
hello(name)

def hello(to='world'):
    print('hello,', to)
# Out:
# hello, world
# hello, Deepjyoti

# %%
# Solving the problem that arises due to calling function before defining it
# and also demonstrating how to access a variable of global scope
count = 1

def main():
    hello()
    name = input("What's your name? ")
    hello(name)

def hello(to='world'):
    global count
    print(f'PS-{count}: hello, {to}')
    count += 1

# Always call main() function at the end of the program
main()
# Out:
# PS-1: hello, world
# PS-2: hello, Deepjyoti

# %%
# Calculate and return the square of a user input number using functions
def main():
    x = int(input("What's the value of x? "))
    print(f'{x} square is: {square(x)}')

def square(n):
    # return n ** 2
    # return pow(n, 2)
    return n * n

main()
# Out:
# 4 square is: 16
